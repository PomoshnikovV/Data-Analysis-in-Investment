# %%
import pandas as pd
import numpy as np

elections = pd.read_csv('Election.csv', sep =';')
elections_new = elections.set_index('State')
elections_new
# Out:
#                      Total Turnout                       Status  \
# State
# United States          112 030 874                          NaN
# Alabama                  1 424 087                    Certified
# Alaska                     267 047                     Official
# Arizona                  2 592 313                    Certified
# Arkansas                   914 227                     Official
# California              11 146 610                    Certified
# Colorado                 2 540 666                     Official
# Connecticut              1 297 811                     Official
# Delaware                   325 632                     Official
# District of Columbia       205 774                    Certified
# Florida                  7 796 916                     Official
# Georgia                  3 964 926                     Official
# Hawaii                     423 443                        Final
# ...

# %%
print(elections_new.head(3))
print(elections_new.tail(1))
# Out:
#               Total Turnout     Status  \
# State
# United States   112 030 874        NaN
# Alabama           1 424 087  Certified
# Alaska              267 047   Official
#
#                                                           Source Turnout Rate  \
# State
# United States                                                NaN        46,2%
# Alabama        https://www2.alabamavotes.gov/electionnight/st...        37,3%
# Alaska         https://www.elections.alaska.gov/election-resu...        50,2%
#
#               Voting-Eligible Population (VEP) Voting-Age Population (VAP)  \
# State
# United States                      242 690 810                 261 673 203
# Alabama                              3 820 009                   3 977 770
# Alaska                                 531 448                     558 308
#
#               % Non-citizen     Prison  Probation   Parole  \
# State
# United States          7,5%  1 157 707  1 145 315  340 972
# ...

# %%
elections_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, United States to Wyoming
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Total Turnout                     52 non-null     object
#  1   Status                            51 non-null     object
#  2   Source                            51 non-null     object
#  3   Turnout Rate                      52 non-null     object
#  4   Voting-Eligible Population (VEP)  52 non-null     object
#  5   Voting-Age Population (VAP)       52 non-null     object
#  6   % Non-citizen                     52 non-null     object
#  7   Prison                            52 non-null     object
#  8   Probation                         52 non-null     object
#  9   Parole                            52 non-null     object
#  10  Total Ineligible Felon            52 non-null     object
# ...

# %%
elections_new.shape
# Out:
# (52, 12)

# %%
elections_new.dtypes
# Out:
# Total Turnout                       object
# Status                              object
# Source                              object
# Turnout Rate                        object
# Voting-Eligible Population (VEP)    object
# Voting-Age Population (VAP)         object
# % Non-citizen                       object
# Prison                              object
# Probation                           object
# Parole                              object
# Total Ineligible Felon              object
# Overseas Eligible                   object
# dtype: object

# %%
elections_new.columns
# Out:
# Index(['Total Turnout', 'Status', 'Source', 'Turnout Rate',
#        'Voting-Eligible Population (VEP)', 'Voting-Age Population (VAP)',
#        '% Non-citizen', 'Prison', 'Probation', 'Parole',
#        'Total Ineligible Felon', 'Overseas Eligible'],
#       dtype='object')

# %%
# elections_new.columns
y = ['Status', '% Non-citizen', 'Parole']
elections_new[y]
# Out:
#                                            Status % Non-citizen   Parole
# State
# United States                                 NaN          7,5%  340 972
# Alabama                                 Certified          2,3%    8 245
# Alaska                                   Official          3,5%    1 003
# Arizona                                 Certified          7,9%    6 887
# Arkansas                                 Official          3,6%   25 852
# California                              Certified         14,6%        0
# Colorado                                 Official          5,8%        0
# Connecticut                              Official          7,6%        0
# Delaware                                 Official          5,1%      373
# District of Columbia                    Certified          7,7%        0
# Florida                                  Official          9,4%    4 280
# Georgia                                  Official          5,9%   19 447
# ...

# %%
print(elections_new['Status'].unique())
len(elections_new['Status'].unique())
# Out:
# [nan 'Certified' 'Official' 'Final' 'Final Total Turnout Pending']
# 5

# %%
# выбор рядов, объединение таблиц по колонкам
df1 = elections_new[0:3]
df2 = elections_new[2:4]
df2
# Out:
#         Total Turnout     Status  \
# State
# Alaska        267 047   Official
# Arizona     2 592 313  Certified
#
#                                                     Source Turnout Rate  \
# State
# Alaska   https://www.elections.alaska.gov/election-resu...        50,2%
# Arizona                        https://azsos.gov/elections        49,3%
#
#         Voting-Eligible Population (VEP) Voting-Age Population (VAP)  \
# State
# Alaska                           531 448                     558 308
# Arizona                        5 257 070                   5 806 140
#
#         % Non-citizen  Prison Probation Parole Total Ineligible Felon  \
# State
# Alaska           3,5%   4 578     1 682  1 003                  7 263
# Arizona          7,9%  34 997    50 333  6 887                 92 217
#
#         Overseas Eligible
# State
# Alaska                NaN
# Arizona               NaN

# %%
# объединение таблиц с одинаковыми колонками
pd.concat([df1, df2], ignore_index=True)
# Out:
#   Total Turnout     Status                                             Source  \
# 0   112 030 874        NaN                                                NaN
# 1     1 424 087  Certified  https://www2.alabamavotes.gov/electionnight/st...
# 2       267 047   Official  https://www.elections.alaska.gov/election-resu...
# 3       267 047   Official  https://www.elections.alaska.gov/election-resu...
# 4     2 592 313  Certified                        https://azsos.gov/elections
#
#   Turnout Rate Voting-Eligible Population (VEP) Voting-Age Population (VAP)  \
# 0        46,2%                      242 690 810                 261 673 203
# 1        37,3%                        3 820 009                   3 977 770
# 2        50,2%                          531 448                     558 308
# 3        50,2%                          531 448                     558 308
# 4        49,3%                        5 257 070                   5 806 140
#
# ...

# %%
df3 = pd.DataFrame([['Official', 2, 2],
                   ['Certified', 2, 2]],
                  columns = ['Status', 'Prison', 'Probation'])
df3
# Out:
#       Status  Prison  Probation
# 0   Official       2          2
# 1  Certified       2          2

# %%
# объединение столбцов по одинаковому столбцу

df3.merge(df2, left_on='Status', right_on='Status', suffixes=('_df3', '_df2'))
# Out:
#       Status  Prison_df3  Probation_df3 Total Turnout  \
# 0   Official           2              2       267 047
# 1  Certified           2              2     2 592 313
#
#                                               Source Turnout Rate  \
# 0  https://www.elections.alaska.gov/election-resu...        50,2%
# 1                        https://azsos.gov/elections        49,3%
#
#   Voting-Eligible Population (VEP) Voting-Age Population (VAP) % Non-citizen  \
# 0                          531 448                     558 308          3,5%
# 1                        5 257 070                   5 806 140          7,9%
#
#   Prison_df2 Probation_df2 Parole Total Ineligible Felon Overseas Eligible
# 0      4 578         1 682  1 003                  7 263               NaN
# 1     34 997        50 333  6 887                 92 217               NaN

# %%
# добавление индексов для таблицы
elections.set_index('State')
# Out:
#                      Total Turnout                       Status  \
# State
# United States          112 030 874                          NaN
# Alabama                  1 424 087                    Certified
# Alaska                     267 047                     Official
# Arizona                  2 592 313                    Certified
# Arkansas                   914 227                     Official
# California              11 146 610                    Certified
# Colorado                 2 540 666                     Official
# Connecticut              1 297 811                     Official
# Delaware                   325 632                     Official
# District of Columbia       205 774                    Certified
# Florida                  7 796 916                     Official
# Georgia                  3 964 926                     Official
# Hawaii                     423 443                        Final
# ...

# %%
# поиск по строкам
elections_new.loc[['Texas', 'Vermont']]
# Out:
#         Total Turnout     Status  \
# State
# Texas       8 151 590   Official
# Vermont       291 955  Certified
#
#                                                     Source Turnout Rate  \
# State
# Texas             https://results.texas-election.com/races        41,8%
# Vermont  https://sos.vermont.gov/elections/election-inf...        56,0%
#
#         Voting-Eligible Population (VEP) Voting-Age Population (VAP)  \
# State
# Texas                         19 499 000                  22 746 809
# Vermont                          521 758                     533 545
#
#         % Non-citizen   Prison Probation   Parole Total Ineligible Felon  \
# State
# Texas           12,2%  128 653   230 704  110 437                469 794
# Vermont          2,0%        0         0        0                      0
#
#         Overseas Eligible
# State
# Texas                 NaN
# Vermont               NaN

# %%
elections_new.query('Status == "Certified"')
# Out:
#                      Total Turnout     Status  \
# State
# Alabama                  1 424 087  Certified
# Arizona                  2 592 313  Certified
# California              11 146 610  Certified
# District of Columbia       205 774  Certified
# Illinois                 4 144 125  Certified
# Maine                      680 909  Certified
# Mississippi                709 100  Certified
# Montana                    468 326  Certified
# Nevada                   1 023 617  Certified
# New Hampshire              626 931  Certified
# New York                 5 962 278  Certified
# Rhode Island               361 449  Certified
# Tennessee                1 756 397  Certified
# Utah                     1 084 634  Certified
# Vermont                    291 955  Certified
# Wisconsin                2 673 154  Certified
#
#                                                                  Source  \
# State
# Alabama               https://www2.alabamavotes.gov/electionnight/st...
# ...

# %%
# методы описания таблицы
elections_new.describe()
elections_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, United States to Wyoming
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Total Turnout                     52 non-null     object
#  1   Status                            51 non-null     object
#  2   Source                            51 non-null     object
#  3   Turnout Rate                      52 non-null     object
#  4   Voting-Eligible Population (VEP)  52 non-null     object
#  5   Voting-Age Population (VAP)       52 non-null     object
#  6   % Non-citizen                     52 non-null     object
#  7   Prison                            52 non-null     object
#  8   Probation                         52 non-null     object
#  9   Parole                            52 non-null     object
#  10  Total Ineligible Felon            52 non-null     object
# ...

# %%
elections_new['Prison'] = [int(x.replace(" ", "")) for x in elections_new['Prison']]
elections_new['Prison']
# Out:
# State
# United States           1157707
# Alabama                   25328
# Alaska                     4578
# Arizona                   34997
# Arkansas                  15850
# California                97328
# Colorado                  14990
# Connecticut                9297
# Delaware                   4653
# District of Columbia          0
# Florida                   75977
# Georgia                   44796
# Hawaii                     4097
# Idaho                      7996
# Illinois                  28582
# Indiana                   23458
# Iowa                       8128
# Kansas                     8477
# Kentucky                  18433
# Louisiana                 26851
# Maine                         0
# Maryland                  14918
# Massachusetts              5993
# Michigan                  33246
# Minnesota                  7681
# Mississippi               17569
# Missouri                  22890
# Montana                    3910
# Nebraska                   5071
# ...

# %%
elections_new['% Non-citizen'] = [float(x.replace("%", "").replace(",", ".")) for x in elections_new['% Non-citizen']]
elections_new['% Non-citizen']
# Out:
# State
# United States            7.5
# Alabama                  2.3
# Alaska                   3.5
# Arizona                  7.9
# Arkansas                 3.6
# California              14.6
# Colorado                 5.8
# Connecticut              7.6
# Delaware                 5.1
# District of Columbia     7.7
# Florida                  9.4
# Georgia                  5.9
# Hawaii                   8.2
# Idaho                    4.0
# Illinois                 7.9
# Indiana                  3.6
# Iowa                     3.1
# Kansas                   4.7
# Kentucky                 2.5
# Louisiana                2.9
# Maine                    1.9
# Maryland                 8.1
# Massachusetts            8.9
# Michigan                 3.3
# Minnesota                4.0
# Mississippi              1.4
# Missouri                 2.3
# Montana                  1.4
# Nebraska                 4.7
# Nevada                  10.3
# New Hampshire            2.6
# New Jersey              11.2
# ...

# %%
elections_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, United States to Wyoming
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Total Turnout                     52 non-null     object
#  1   Status                            51 non-null     object
#  2   Source                            51 non-null     object
#  3   Turnout Rate                      52 non-null     object
#  4   Voting-Eligible Population (VEP)  52 non-null     object
#  5   Voting-Age Population (VAP)       52 non-null     object
#  6   % Non-citizen                     52 non-null     float64
#  7   Prison                            52 non-null     int64
#  8   Probation                         52 non-null     object
#  9   Parole                            52 non-null     object
#  10  Total Ineligible Felon            52 non-null     object
# ...
